# %%
! pip install -q scikit-plot
# !wget http://nlp.stanford.edu/data/glove.6B.zip
# !unzip -q glove.6B.zip

# %% [markdown]
# # **Import**

# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)
import string
import numpy as np

# %%
import sys
filePath = '/Users/pratiksayanekar/Documents/DL_20200161'
#filePath = '/content/drive/My Drive/DeepLearning'
sys.path.append(filePath)

# %%
from utils.basic_utilities import Utils
from models.LSTM_1 import LSTM_Model
from models.CNN_1 import CNN_Model
from models.Word2Vec_1 import Word2VecModel
from models.BiLSTM import BiLSTM_Model

# %%
from sklearn.metrics import classification_report

# %% [markdown]
# # **Reading Preprocessed Data**

# %%
#df = pd.read_csv('/content/drive/MyDrive/DeepLearning/Data/preprocessed_data.csv')
df = pd.read_csv('{}/Data/preprocessed_data.csv'.format(filePath))
df.head()
# Out:
#         emotion  \
# 0  disappointed
# 1  disappointed
# 2  disappointed
# 3         happy
# 4  disappointed
#
#                                                                                                                                                   content  \
# 0                                                                              oh fuck did i wrote fil grinningfacewithsweat nsorry spot disappointedface
# 1                                                                                                                            i feel nor am i shamed by it
# 2                                       i had been feeling a little bit defeated by the step of faith we would need to take to try to resolve our problem
# 3                                                               imagine if that reaction guy that called jj kfc saw this my man would ve started cry lmao
# 4  i wouldnt feel burdened so that i would live my life a a testament to his sacrifice that wa out of a love so pure and innocent yet so great and mighty
#
#                                                                                                                                            original_content  \
# 0                                b'RT @Davbingodav: @mcrackins Oh fuck.... did I wrote Fil ??? :grinning_face_with_sweat:\nSorry Spot. :disappointed_face:'
# 1                                                                                                                              i feel nor am i shamed by it
# 2                                        i had been feeling a little bit defeated by the steps of faith we would need to take to try to resolve our problem
# 3                                           b"@KSIOlajidebt imagine if that reaction guy that called JJ KFC saw this. my man would've started crying lmao "
# 4  i wouldnt feel burdened so that i would live my life as a testament to his sacrifice that was out of a love so pure and innocent yet so great and mighty
#
#                                                                                   text
# 0            rt oh fuck wrote fil grinning_face_with_sweatnsorry spot isappointed_face
# 1                                                                          feel shamed
# 2                     feeling little bit defeated steps faith need try resolve problem
# 3                    imagine reaction guy called jj kfc saw man ve started crying lmao
# 4  wouldnt feel burdened live life testament sacrifice love pure innocent great mighty

# %%
df.text = df.text.astype(str)

# %% [markdown]
# # **Splitting dataset into train(80%) and test(20%)**

# %%
util = Utils()
X_train, X_test, y_train, y_test = util.split_data(df)
print("The shape of train data: ",X_train.shape)
print("The shape of train target: ",y_train.shape)
print("The shape of test data: ",X_test.shape)
print("The shape of test target: ",y_test.shape)
# Out:
# Initialization of Utilities...
# The shape of train data:  (733260,)
# The shape of train target:  (733260,)
# The shape of test data:  (183315,)
# The shape of test target:  (183315,)

# %%
y_test.value_counts()
# Out:
# disappointed    62743
# happy           60374
# angry           60198
# Name: emotion, dtype: int64

# %%
target_converted_train, target_converted_test = util.one_hot_target_variable(y_train, y_test)
print("After one hot encoding of target variable...")
print("The shape of train target: ", target_converted_train.shape)
print("The shape of test target: ", target_converted_test.shape)
# Out:
# After one hot encoding of target variable...
# The shape of train target:  (733260, 3)
# The shape of test target:  (183315, 3)

# %% [markdown]
# # **Tokenization and Padding of each tweet**

# %%
# max_len = util.max_len(df)
max_len = 100
print("Maximum length of tweet:", max_len)
# Out:
# Maximum length of tweet: 122

# %%
train_converted, test_converted, tokenizer = util.tokenization_padding_oov_token(X_train, X_test, max_len)
print("After Tokenization and Padding...")
print("The shape of train data: ", train_converted.shape)
print("The shape of test data: ", test_converted.shape)
# Out:
# After Tokenization and Padding...
# The shape of train data:  (733260, 122)
# The shape of test data:  (183315, 122)

# %%
vocab_length = len(tokenizer.word_index) + 1
# Out:
# Embedding Matrix Shape: (159426, 122)

# %% [markdown]
# # Glove : Pretrained word embedding

# %%
path_to_glove_file = '{}/Data/glove.6B.100d.txt'.format(filePath)

embeddings_index = {}
with open(path_to_glove_file) as f:
    for line in f:
        word, coefs = line.split(maxsplit=1)
        coefs = np.fromstring(coefs, "f", sep=" ")
        embeddings_index[word] = coefs

print("Found %s word vectors." % len(embeddings_index))

hits = 0
misses = 0

# Prepare embedding matrix
embedding_matrix = np.zeros((vocab_length, 100))
for word, token in tokenizer.word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        # Words not found in embedding index will be all-zeros.
        # This includes the representation for "padding" and "OOV"
        embedding_matrix[token] = embedding_vector
        hits += 1
    else:
        misses += 1
        
print("Embedding Matrix Shape:", embedding_matrix.shape)
# Out:
# Found 400000 word vectors.
# After Tokenization and Padding...
# The shape of train data:  (733260, 100)
# The shape of test data:  (183315, 100)
# Embedding Matrix Shape: (159426, 100)

# %% [markdown]
# # **Deep Learning Models**

# %%
EPOCH = 10
BATCH_SIZE = 2048 # 1024

# %% [markdown]
# # **CNN Model**

# %%
# Below method is commented as now for embedding layer some weight matrix is also provided as input.

# cnn = CNN_Model()
# model = cnn.create_model(embed_dim = 100, num_filters = 128, 
#                           input_len = train_converted.shape[1], feature = 200000, 
#                           drop_out = 0.5, num_words=4)
# model.summary()

# %%
cnn = CNN_Model()
model = cnn.create_model(embed_dim = max_len, num_filters = 128, 
                          input_len = train_converted.shape[1], feature = vocab_length, 
                          drop_out = 0.5, num_words=4, embedding_matrix = embedding_matrix)
model.summary()
# Out:
# CNN Model Initialization...
# Model Created Successfully...
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 100, 100)          15942600
# _________________________________________________________________
# spatial_dropout1d (SpatialDr (None, 100, 100)          0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 97, 128)           51328
# _________________________________________________________________
# global_max_pooling1d (Global (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 3)                 387
# =================================================================
# Total params: 15,994,315
# Trainable params: 15,994,315
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(train_converted, target_converted_train, epochs = EPOCH, 
                    batch_size=BATCH_SIZE, validation_split=0.2,
                    callbacks=cnn.callbacks)
# Out:
# Epoch 1/10
# 267/287 [==========================>...] - ETA: 24s - loss: 1.1343 - acc: 0.4463
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-b6a9a799cab5> in <module>
# ----> 1 history = model.fit(train_converted, target_converted_train, epochs = EPOCH,
#       2                     batch_size=BATCH_SIZE, validation_split=0.2,
#       3                     callbacks=cnn.callbacks)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1098                 _r=1):
#    1099               callbacks.on_train_batch_begin(step)
# -> 1100               tmp_logs = self.train_function(iterator)
#    1101               if data_handler.should_sync:
#    1102                 context.async_wait()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     853       # In this case we have created variables on the first call, so we run the
#     854       # defunned version which is guaranteed to never create variables.
# --> 855       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     856     elif self._stateful_fn is not None:
#     857       # Release the lock early so that multiple threads can perform the call
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2940       (graph_function,
#    2941        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2942     return graph_function._call_flat(
#    2943         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2944
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1916         and executing_eagerly):
#    1917       # No tape is watching; skip to running the function.
# -> 1918       return self._build_call_outputs(self._inference_function.call(
#    1919           ctx, args, cancellation_manager=cancellation_manager))
#    1920     forward_backward = self._select_forward_and_backward_functions(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     553       with _InterpolateFunctionError(self):
#     554         if cancellation_manager is None:
# --> 555           outputs = execute.execute(
#     556               str(self.signature.name),
#     557               num_outputs=self._num_outputs,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
util.plot_accuracy_loss(history, 'CNN')

# %% [markdown]
# # **Evaluation**

# %%
model = cnn.load_saved_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 122, 122)          19449972
# _________________________________________________________________
# spatial_dropout1d (SpatialDr (None, 122, 122)          0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 119, 128)          62592
# _________________________________________________________________
# global_max_pooling1d (Global (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 3)                 387
# =================================================================
# Total params: 19,512,951
# Trainable params: 19,512,951
# Non-trainable params: 0
# _________________________________________________________________

# %%
score, acc = model.evaluate(test_converted, target_converted_test, verbose = 2, batch_size = BATCH_SIZE)
print("The loss of this model: %.2f" % (score))
print("The accuracy of this model: %.2f" % (acc))
# Out:
# 90/90 - 12s - loss: 0.2417 - acc: 0.8939
# The loss of this model: 0.24
# The accuracy of this model: 0.89

# %%
y_pred = model.predict(test_converted)

# %%
test,pred = util.plot_confusion_matrix(y_pred, target_converted_test, 'CNN')
# Out:
# Confusion Matrix:
#  [[56259 10696  3266]
#  [ 3651 51616  1124]
#  [  288   431 55984]]

# %%
print("Classification Report: ", classification_report(test, pred))
# Out:
# Classification Report:                precision    recall  f1-score   support
#
#            0       0.93      0.80      0.86     70221
#            1       0.82      0.92      0.87     56391
#            2       0.93      0.99      0.96     56703
#
#     accuracy                           0.89    183315
#    macro avg       0.89      0.90      0.90    183315
# weighted avg       0.90      0.89      0.89    183315

# %% [markdown]
# # **CNN_v2**

# %%
# Below method is commented as now for embedding layer some weight matrix is also provided as input.

# cnn = CNN_Model()
# model = cnn.create_model_v2(embed_dim = 100, num_filters = 128, 
#                           input_len = train_converted.shape[1], feature = 200000, 
#                           drop_out = 0.8, num_words=4)
# model.summary()

# %%
cnn = CNN_Model()
model = cnn.create_model_v2(embed_dim = max_len, num_filters = 128, 
                          input_len = train_converted.shape[1], feature = vocab_length, 
                          drop_out = 0.5, num_words=4, embedding_matrix = embedding_matrix )
model.summary()
# Out:
# CNN Model Initialization...
# Model Created Successfully...
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 122, 122)          19449972
# _________________________________________________________________
# spatial_dropout1d_1 (Spatial (None, 122, 122)          0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 122, 128)          62592
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 122, 128)          65664
# _________________________________________________________________
# spatial_dropout1d_2 (Spatial (None, 122, 128)          0
# _________________________________________________________________
# global_max_pooling1d_1 (Glob (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 195
# =================================================================
# Total params: 19,586,679
# Trainable params: 19,586,679
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(train_converted, target_converted_train, epochs = EPOCH, 
                    batch_size=BATCH_SIZE, validation_split=0.2,
                    callbacks=cnn.callbacks_v2)
# Out:
# Epoch 1/10
# 287/287 [==============================] - 354s 1s/step - loss: 1.0950 - acc: 0.5057 - val_loss: 0.4871 - val_acc: 0.8061
#
# Epoch 00001: val_loss improved from inf to 0.48709, saving model to /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/CNN_v2/
# INFO:tensorflow:Assets written to: /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/CNN_v2/assets
# Epoch 2/10
# 287/287 [==============================] - 357s 1s/step - loss: 0.5703 - acc: 0.7506 - val_loss: 0.4342 - val_acc: 0.8543
#
# Epoch 00002: val_loss improved from 0.48709 to 0.43420, saving model to /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/CNN_v2/
# INFO:tensorflow:Assets written to: /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/CNN_v2/assets
# Epoch 3/10
# 287/287 [==============================] - 357s 1s/step - loss: 0.4406 - acc: 0.8121 - val_loss: 0.4771 - val_acc: 0.8486
#
# Epoch 00003: val_loss did not improve from 0.43420
# Epoch 4/10
# 287/287 [==============================] - 358s 1s/step - loss: 0.3762 - acc: 0.8402 - val_loss: 0.4157 - val_acc: 0.8588
#
# Epoch 00004: val_loss improved from 0.43420 to 0.41574, saving model to /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/CNN_v2/
# INFO:tensorflow:Assets written to: /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/CNN_v2/assets
# Epoch 5/10
# 287/287 [==============================] - 359s 1s/step - loss: 0.3396 - acc: 0.8547 - val_loss: 0.4030 - val_acc: 0.8617
#
# Epoch 00005: val_loss improved from 0.41574 to 0.40304, saving model to /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/CNN_v2/
# INFO:tensorflow:Assets written to: /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/CNN_v2/assets
# Epoch 6/10
# 287/287 [==============================] - 387s 1s/step - loss: 0.3237 - acc: 0.8599 - val_loss: 0.3882 - val_acc: 0.8564
#
# Epoch 00006: val_loss improved from 0.40304 to 0.38816, saving model to /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/CNN_v2/
# INFO:tensorflow:Assets written to: /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/CNN_v2/assets
# Epoch 7/10
# 287/287 [==============================] - 394s 1s/step - loss: 0.3109 - acc: 0.8653 - val_loss: 0.3650 - val_acc: 0.8626
#
# Epoch 00007: val_loss improved from 0.38816 to 0.36499, saving model to /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/CNN_v2/
# INFO:tensorflow:Assets written to: /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/CNN_v2/assets
# Epoch 8/10
# 287/287 [==============================] - 396s 1s/step - loss: 0.3022 - acc: 0.8688 - val_loss: 0.3587 - val_acc: 0.8625
#
# Epoch 00008: val_loss improved from 0.36499 to 0.35870, saving model to /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/CNN_v2/
# INFO:tensorflow:Assets written to: /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/CNN_v2/assets
# Epoch 9/10
# 287/287 [==============================] - 401s 1s/step - loss: 0.2937 - acc: 0.8722 - val_loss: 0.3413 - val_acc: 0.8649
#
# Epoch 00009: val_loss improved from 0.35870 to 0.34131, saving model to /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/CNN_v2/
# INFO:tensorflow:Assets written to: /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/CNN_v2/assets
# Epoch 10/10
# 287/287 [==============================] - 397s 1s/step - loss: 0.2858 - acc: 0.8760 - val_loss: 0.3596 - val_acc: 0.8619
#
# Epoch 00010: val_loss did not improve from 0.34131

# %%
util.plot_accuracy_loss(history, 'CNN_v2')

# %% [markdown]
# # **Evaluation**

# %%
model = cnn.load_saved_model_v2()
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 122, 122)          19449972
# _________________________________________________________________
# spatial_dropout1d_1 (Spatial (None, 122, 122)          0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 122, 128)          62592
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 122, 128)          65664
# _________________________________________________________________
# spatial_dropout1d_2 (Spatial (None, 122, 128)          0
# _________________________________________________________________
# global_max_pooling1d_1 (Glob (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 195
# =================================================================
# Total params: 19,586,679
# Trainable params: 19,586,679
# Non-trainable params: 0
# _________________________________________________________________

# %%
score, acc = model.evaluate(test_converted, target_converted_test, verbose = 2, batch_size = BATCH_SIZE)
print("The loss of this model: %.2f" % (score))
print("The accuracy of this model: %.2f" % (acc))
# Out:
# 90/90 - 25s - loss: 0.3431 - acc: 0.8632
# The loss of this model: 0.34
# The accuracy of this model: 0.86

# %%
y_pred = model.predict(test_converted)

# %%
test,pred = util.plot_confusion_matrix(y_pred, target_converted_test, 'CNN_v2')
# Out:
# Confusion Matrix:
#  [[55442 12624  4800]
#  [ 4469 49025  1801]
#  [  287  1094 53773]]

# %%
print("Classification Report: ", classification_report(test, pred))
# Out:
# Classification Report:                precision    recall  f1-score   support
#
#            0       0.92      0.76      0.83     72866
#            1       0.78      0.89      0.83     55295
#            2       0.89      0.97      0.93     55154
#
#     accuracy                           0.86    183315
#    macro avg       0.86      0.87      0.86    183315
# weighted avg       0.87      0.86      0.86    183315

# %% [markdown]
# # **LSTM Model**

# %%
# Below method is commented as now for embedding layer some weight matrix is also provided as input.

# lstm = LSTM_Model()
# model = lstm.create_model(embed_dim = 100, lstm_out = 64, 
#                           input_len = train_converted.shape[1], feature = 200000, 
#                           drop_out = 0.8)
# model.summary()

# %%
lstm = LSTM_Model()
model = lstm.create_model(embed_dim = max_len, lstm_out = 64, 
                          input_len = train_converted.shape[1], feature = vocab_length, 
                          drop_out = 0.5, embedding_matrix = embedding_matrix)
model.summary()
# Out:
# LSTM Model Initialization...
# Model Created Successfully...
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 122, 122)          19449972
# _________________________________________________________________
# spatial_dropout1d_3 (Spatial (None, 122, 122)          0
# _________________________________________________________________
# lstm (LSTM)                  (None, 64)                47872
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 195
# =================================================================
# Total params: 19,498,039
# Trainable params: 19,498,039
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(train_converted, target_converted_train, epochs = EPOCH, 
                    batch_size= BATCH_SIZE, validation_split=0.2,
                    callbacks=lstm.callbacks)
# Out:
# Epoch 1/10
# 287/287 [==============================] - 588s 2s/step - loss: 1.0079 - acc: 0.4787 - val_loss: 0.6537 - val_acc: 0.6932
#
# Epoch 00001: val_loss improved from inf to 0.65367, saving model to /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/LSTM/
# INFO:tensorflow:Assets written to: /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/LSTM/assets
# Epoch 2/10
# 287/287 [==============================] - 567s 2s/step - loss: 0.7889 - acc: 0.6372 - val_loss: 0.5538 - val_acc: 0.7696
#
# Epoch 00002: val_loss improved from 0.65367 to 0.55381, saving model to /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/LSTM/
# INFO:tensorflow:Assets written to: /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/LSTM/assets
# Epoch 3/10
# 287/287 [==============================] - 548s 2s/step - loss: 0.7690 - acc: 0.6456 - val_loss: 0.5261 - val_acc: 0.7857
#
# Epoch 00003: val_loss improved from 0.55381 to 0.52605, saving model to /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/LSTM/
# INFO:tensorflow:Assets written to: /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/LSTM/assets
# Epoch 4/10
# 287/287 [==============================] - 527s 2s/step - loss: 0.6760 - acc: 0.6983 - val_loss: 0.4684 - val_acc: 0.8153
#
# Epoch 00004: val_loss improved from 0.52605 to 0.46838, saving model to /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/LSTM/
# INFO:tensorflow:Assets written to: /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/LSTM/assets
# Epoch 5/10
# 287/287 [==============================] - 518s 2s/step - loss: 0.6311 - acc: 0.7234 - val_loss: 0.4087 - val_acc: 0.8389
#
# Epoch 00005: val_loss improved from 0.46838 to 0.40866, saving model to /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/LSTM/
# INFO:tensorflow:Assets written to: /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/LSTM/assets
# Epoch 6/10
# 287/287 [==============================] - 514s 2s/step - loss: 0.5847 - acc: 0.7483 - val_loss: 0.3534 - val_acc: 0.8596
#
# Epoch 00006: val_loss improved from 0.40866 to 0.35342, saving model to /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/LSTM/
# INFO:tensorflow:Assets written to: /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/LSTM/assets
# Epoch 7/10
# 287/287 [==============================] - 510s 2s/step - loss: 0.5384 - acc: 0.7716 - val_loss: 0.3172 - val_acc: 0.8706
#
# Epoch 00007: val_loss improved from 0.35342 to 0.31724, saving model to /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/LSTM/
# INFO:tensorflow:Assets written to: /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/LSTM/assets
# Epoch 8/10
# 287/287 [==============================] - 510s 2s/step - loss: 0.4997 - acc: 0.7906 - val_loss: 0.2961 - val_acc: 0.8749
#
# Epoch 00008: val_loss improved from 0.31724 to 0.29611, saving model to /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/LSTM/
# INFO:tensorflow:Assets written to: /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/LSTM/assets
# Epoch 9/10
# 287/287 [==============================] - 508s 2s/step - loss: 0.4636 - acc: 0.8074 - val_loss: 0.2831 - val_acc: 0.8787
#
# Epoch 00009: val_loss improved from 0.29611 to 0.28308, saving model to /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/LSTM/
# INFO:tensorflow:Assets written to: /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/LSTM/assets
# Epoch 10/10
# 287/287 [==============================] - 505s 2s/step - loss: 0.4353 - acc: 0.8200 - val_loss: 0.2740 - val_acc: 0.8821
#
# Epoch 00010: val_loss improved from 0.28308 to 0.27398, saving model to /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/LSTM/
# INFO:tensorflow:Assets written to: /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/LSTM/assets

# %%
util.plot_accuracy_loss(history, 'LSTM')

# %% [markdown]
# # **Evaluation**

# %%
model = lstm.load_saved_model()
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 122, 122)          19449972
# _________________________________________________________________
# spatial_dropout1d_3 (Spatial (None, 122, 122)          0
# _________________________________________________________________
# lstm (LSTM)                  (None, 64)                47872
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 195
# =================================================================
# Total params: 19,498,039
# Trainable params: 19,498,039
# Non-trainable params: 0
# _________________________________________________________________

# %%
score, acc = model.evaluate(test_converted, target_converted_test, verbose = 2, batch_size = BATCH_SIZE)
print("The loss of this model: %.2f" % (score))
print("The accuracy of this model: %.2f" % (acc))
# Out:
# 90/90 - 30s - loss: 0.2767 - acc: 0.8810
# The loss of this model: 0.28
# The accuracy of this model: 0.88

# %%
y_pred = model.predict(test_converted)

# %%
test, pred = util.plot_confusion_matrix(y_pred, target_converted_test, 'LSTM')
# Out:
# Confusion Matrix:
#  [[56634 12631  3880]
#  [ 3030 49522  1146]
#  [  534   590 55348]]

# %%
print("Classification Report: ", classification_report(test, pred))
# Out:
# Classification Report:                precision    recall  f1-score   support
#
#            0       0.94      0.77      0.85     73145
#            1       0.79      0.92      0.85     53698
#            2       0.92      0.98      0.95     56472
#
#     accuracy                           0.88    183315
#    macro avg       0.88      0.89      0.88    183315
# weighted avg       0.89      0.88      0.88    183315

# %% [markdown]
# # **LSTM_v2**

# %%
# Below method is commented as now for embedding layer some weight matrix is also provided as input.

# lstm = LSTM_Model()
# model = lstm.create_model_v2(embed_dim = 100, lstm_out = 64, 
#                           input_len = train_converted.shape[1], feature = 200000, 
#                           drop_out = 0.8)
# model.summary()

# %%
lstm = LSTM_Model()
model = lstm.create_model_v2(embed_dim = max_len, lstm_out = 64, 
                          input_len = train_converted.shape[1], feature = vocab_length, 
                          drop_out = 0.5, embedding_matrix = embedding_matrix )
model.summary()
# Out:
# LSTM Model Initialization...
# Model Created Successfully...
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 122, 122)          19449972
# _________________________________________________________________
# spatial_dropout1d_4 (Spatial (None, 122, 122)          0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 122, 64)           47872
# _________________________________________________________________
# spatial_dropout1d_5 (Spatial (None, 122, 64)           0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 122, 64)           33024
# _________________________________________________________________
# global_max_pooling1d_2 (Glob (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_5 (Dense)              (None, 3)                 195
# =================================================================
# Total params: 19,535,223
# Trainable params: 19,535,223
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(train_converted, target_converted_train, epochs = EPOCH, 
                    batch_size= BATCH_SIZE, validation_split=0.2,
                    callbacks=lstm.callbacks_v2)
# Out:
# Epoch 1/10
# 287/287 [==============================] - 1156s 4s/step - loss: 1.0909 - acc: 0.3713 - val_loss: 0.9554 - val_acc: 0.5467
#
# Epoch 00001: val_loss improved from inf to 0.95540, saving model to /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/LSTM_v2/
# INFO:tensorflow:Assets written to: /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/LSTM_v2/assets
# Epoch 2/10
# 287/287 [==============================] - 1159s 4s/step - loss: 1.0475 - acc: 0.4355 - val_loss: 0.7878 - val_acc: 0.6073
#
# Epoch 00002: val_loss improved from 0.95540 to 0.78782, saving model to /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/LSTM_v2/
# INFO:tensorflow:Assets written to: /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/LSTM_v2/assets
# Epoch 3/10
# 287/287 [==============================] - 1182s 4s/step - loss: 0.9791 - acc: 0.4938 - val_loss: 0.7483 - val_acc: 0.6745
#
# Epoch 00003: val_loss improved from 0.78782 to 0.74827, saving model to /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/LSTM_v2/
# INFO:tensorflow:Assets written to: /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/LSTM_v2/assets
# Epoch 4/10
# 287/287 [==============================] - 1340s 5s/step - loss: 0.9281 - acc: 0.5310 - val_loss: 0.7073 - val_acc: 0.6828
#
# Epoch 00004: val_loss improved from 0.74827 to 0.70726, saving model to /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/LSTM_v2/
# INFO:tensorflow:Assets written to: /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/LSTM_v2/assets
# Epoch 5/10
# 287/287 [==============================] - 1070s 4s/step - loss: 0.8871 - acc: 0.5599 - val_loss: 0.6568 - val_acc: 0.6860
#
# Epoch 00005: val_loss improved from 0.70726 to 0.65680, saving model to /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/LSTM_v2/
# INFO:tensorflow:Assets written to: /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/LSTM_v2/assets
# Epoch 6/10
# 287/287 [==============================] - 858s 3s/step - loss: 0.8539 - acc: 0.5817 - val_loss: 0.6243 - val_acc: 0.6962
#
# Epoch 00006: val_loss improved from 0.65680 to 0.62427, saving model to /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/LSTM_v2/
# INFO:tensorflow:Assets written to: /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/LSTM_v2/assets
# Epoch 7/10
# 287/287 [==============================] - 851s 3s/step - loss: 0.8262 - acc: 0.6012 - val_loss: 0.5916 - val_acc: 0.7072
#
# Epoch 00007: val_loss improved from 0.62427 to 0.59157, saving model to /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/LSTM_v2/
# INFO:tensorflow:Assets written to: /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/LSTM_v2/assets
# Epoch 8/10
# 287/287 [==============================] - 839s 3s/step - loss: 0.7970 - acc: 0.6241 - val_loss: 0.5481 - val_acc: 0.7670
#
# Epoch 00008: val_loss improved from 0.59157 to 0.54809, saving model to /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/LSTM_v2/
# INFO:tensorflow:Assets written to: /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/LSTM_v2/assets
# Epoch 9/10
# 287/287 [==============================] - 831s 3s/step - loss: 0.7696 - acc: 0.6420 - val_loss: 0.5117 - val_acc: 0.7890
#
# Epoch 00009: val_loss improved from 0.54809 to 0.51169, saving model to /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/LSTM_v2/
# INFO:tensorflow:Assets written to: /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/LSTM_v2/assets
# Epoch 10/10
# 287/287 [==============================] - 834s 3s/step - loss: 0.7436 - acc: 0.6603 - val_loss: 0.4822 - val_acc: 0.8082
#
# Epoch 00010: val_loss improved from 0.51169 to 0.48217, saving model to /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/LSTM_v2/
# INFO:tensorflow:Assets written to: /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/LSTM_v2/assets

# %%
util.plot_accuracy_loss(history, 'LSTM_v2')

# %% [markdown]
# # **Evaluation**

# %%
model = lstm.load_saved_model_v2()
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 122, 122)          19449972
# _________________________________________________________________
# spatial_dropout1d_4 (Spatial (None, 122, 122)          0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 122, 64)           47872
# _________________________________________________________________
# spatial_dropout1d_5 (Spatial (None, 122, 64)           0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 122, 64)           33024
# _________________________________________________________________
# global_max_pooling1d_2 (Glob (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_5 (Dense)              (None, 3)                 195
# =================================================================
# Total params: 19,535,223
# Trainable params: 19,535,223
# Non-trainable params: 0
# _________________________________________________________________

# %%
score, acc = model.evaluate(test_converted, target_converted_test, verbose = 2, batch_size = BATCH_SIZE)
print("The loss of this model: %.2f" % (score))
print("The accuracy of this model: %.2f" % (acc))
# Out:
# 90/90 - 51s - loss: 0.4852 - acc: 0.8074
# The loss of this model: 0.49
# The accuracy of this model: 0.81

# %%
y_pred = model.predict(test_converted)

# %%
test, pred = util.plot_confusion_matrix(y_pred, target_converted_test, 'LSTM_v2')
# Out:
# Confusion Matrix:
#  [[48586 15399  3462]
#  [ 9430 44055  1543]
#  [ 2182  3289 55369]]

# %%
print("Classification Report: ", classification_report(test, pred))
# Out:
# Classification Report:                precision    recall  f1-score   support
#
#            0       0.81      0.72      0.76     67447
#            1       0.70      0.80      0.75     55028
#            2       0.92      0.91      0.91     60840
#
#     accuracy                           0.81    183315
#    macro avg       0.81      0.81      0.81    183315
# weighted avg       0.81      0.81      0.81    183315

# %% [markdown]
# # **BiLSTM**

# %%
bi_lstm = BiLSTM_Model()
model = bi_lstm.create_model(embed_dim = max_len, lstm_out = 100, input_len = train_converted.shape[1], 
                             feature = vocab_length, drop_out = 0.5, embedding_matrix = embedding_matrix)
model.summary()
# Out:
# BiLSTM Model Initialization...
# Model Created Successfully...
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_4 (Embedding)      (None, 122, 122)          19449972
# _________________________________________________________________
# bidirectional (Bidirectional (None, 122, 200)          178400
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 122, 200)          240800
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 118, 100)          100100
# _________________________________________________________________
# global_max_pooling1d_3 (Glob (None, 100)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 16)                1616
# _________________________________________________________________
# dense_7 (Dense)              (None, 3)                 51
# =================================================================
# Total params: 19,970,939
# Trainable params: 19,970,939
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(train_converted, target_converted_train, batch_size=BATCH_SIZE, epochs=EPOCH,
                    validation_split=0.2, callbacks=bi_lstm.callbacks)
# Out:
# Epoch 1/10
# 287/287 [==============================] - 3824s 13s/step - loss: 0.6719 - acc: 0.6967 - val_loss: 0.2712 - val_acc: 0.8852
# WARNING:absl:Found untraced functions such as lstm_cell_7_layer_call_and_return_conditional_losses, lstm_cell_7_layer_call_fn, lstm_cell_8_layer_call_and_return_conditional_losses, lstm_cell_8_layer_call_fn, lstm_cell_10_layer_call_and_return_conditional_losses while saving (showing 5 of 20). These functions will not be directly callable after loading.
# WARNING:absl:Found untraced functions such as lstm_cell_7_layer_call_and_return_conditional_losses, lstm_cell_7_layer_call_fn, lstm_cell_8_layer_call_and_return_conditional_losses, lstm_cell_8_layer_call_fn, lstm_cell_10_layer_call_and_return_conditional_losses while saving (showing 5 of 20). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/BiLSTM/assets
# INFO:tensorflow:Assets written to: /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/BiLSTM/assets
# Epoch 2/10
# 287/287 [==============================] - 4341s 15s/step - loss: 0.3377 - acc: 0.8548 - val_loss: 0.2422 - val_acc: 0.8948
# WARNING:absl:Found untraced functions such as lstm_cell_7_layer_call_and_return_conditional_losses, lstm_cell_7_layer_call_fn, lstm_cell_8_layer_call_and_return_conditional_losses, lstm_cell_8_layer_call_fn, lstm_cell_10_layer_call_and_return_conditional_losses while saving (showing 5 of 20). These functions will not be directly callable after loading.
# WARNING:absl:Found untraced functions such as lstm_cell_7_layer_call_and_return_conditional_losses, lstm_cell_7_layer_call_fn, lstm_cell_8_layer_call_and_return_conditional_losses, lstm_cell_8_layer_call_fn, lstm_cell_10_layer_call_and_return_conditional_losses while saving (showing 5 of 20). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/BiLSTM/assets
# INFO:tensorflow:Assets written to: /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/BiLSTM/assets
# Epoch 3/10
# 287/287 [==============================] - 3866s 13s/step - loss: 0.2817 - acc: 0.8792 - val_loss: 0.2336 - val_acc: 0.8990
# WARNING:absl:Found untraced functions such as lstm_cell_7_layer_call_and_return_conditional_losses, lstm_cell_7_layer_call_fn, lstm_cell_8_layer_call_and_return_conditional_losses, lstm_cell_8_layer_call_fn, lstm_cell_10_layer_call_and_return_conditional_losses while saving (showing 5 of 20). These functions will not be directly callable after loading.
# WARNING:absl:Found untraced functions such as lstm_cell_7_layer_call_and_return_conditional_losses, lstm_cell_7_layer_call_fn, lstm_cell_8_layer_call_and_return_conditional_losses, lstm_cell_8_layer_call_fn, lstm_cell_10_layer_call_and_return_conditional_losses while saving (showing 5 of 20). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/BiLSTM/assets
# INFO:tensorflow:Assets written to: /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/BiLSTM/assets
# Epoch 4/10
# 287/287 [==============================] - 3363s 12s/step - loss: 0.2569 - acc: 0.8893 - val_loss: 0.2292 - val_acc: 0.8997
# WARNING:absl:Found untraced functions such as lstm_cell_7_layer_call_and_return_conditional_losses, lstm_cell_7_layer_call_fn, lstm_cell_8_layer_call_and_return_conditional_losses, lstm_cell_8_layer_call_fn, lstm_cell_10_layer_call_and_return_conditional_losses while saving (showing 5 of 20). These functions will not be directly callable after loading.
# WARNING:absl:Found untraced functions such as lstm_cell_7_layer_call_and_return_conditional_losses, lstm_cell_7_layer_call_fn, lstm_cell_8_layer_call_and_return_conditional_losses, lstm_cell_8_layer_call_fn, lstm_cell_10_layer_call_and_return_conditional_losses while saving (showing 5 of 20). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/BiLSTM/assets
# INFO:tensorflow:Assets written to: /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/BiLSTM/assets
# Epoch 5/10
# 287/287 [==============================] - 3597s 13s/step - loss: 0.2415 - acc: 0.8962 - val_loss: 0.2249 - val_acc: 0.9025
# WARNING:absl:Found untraced functions such as lstm_cell_7_layer_call_and_return_conditional_losses, lstm_cell_7_layer_call_fn, lstm_cell_8_layer_call_and_return_conditional_losses, lstm_cell_8_layer_call_fn, lstm_cell_10_layer_call_and_return_conditional_losses while saving (showing 5 of 20). These functions will not be directly callable after loading.
# WARNING:absl:Found untraced functions such as lstm_cell_7_layer_call_and_return_conditional_losses, lstm_cell_7_layer_call_fn, lstm_cell_8_layer_call_and_return_conditional_losses, lstm_cell_8_layer_call_fn, lstm_cell_10_layer_call_and_return_conditional_losses while saving (showing 5 of 20). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/BiLSTM/assets
# INFO:tensorflow:Assets written to: /Users/pratiksayanekar/Documents/DL_20200161/checkpoints/BiLSTM/assets
# Epoch 6/10
# 287/287 [==============================] - 3954s 14s/step - loss: 0.2272 - acc: 0.9033 - val_loss: 0.2259 - val_acc: 0.9023
# Epoch 7/10
# 287/287 [==============================] - 3308s 12s/step - loss: 0.2094 - acc: 0.9111 - val_loss: 0.2274 - val_acc: 0.9022
# Epoch 8/10
# 287/287 [==============================] - 3248s 11s/step - loss: 0.1945 - acc: 0.9174 - val_loss: 0.2321 - val_acc: 0.9016
# Epoch 9/10
# 287/287 [==============================] - 3265s 11s/step - loss: 0.1836 - acc: 0.9214 - val_loss: 0.2345 - val_acc: 0.9016
# Epoch 10/10
# 287/287 [==============================] - 3263s 11s/step - loss: 0.1754 - acc: 0.9243 - val_loss: 0.2455 - val_acc: 0.9001

# %% [markdown]
# # **Evaluation**

# %%
model = bi_lstm.load_saved_model()
print(model.summary())
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_4 (Embedding)      (None, 122, 122)          19449972
# _________________________________________________________________
# bidirectional (Bidirectional (None, 122, 200)          178400
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 122, 200)          240800
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 118, 100)          100100
# _________________________________________________________________
# global_max_pooling1d_3 (Glob (None, 100)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 16)                1616
# _________________________________________________________________
# dense_7 (Dense)              (None, 3)                 51
# =================================================================
# Total params: 19,970,939
# Trainable params: 19,970,939
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
score, acc = model.evaluate(test_converted, target_converted_test, verbose = 2, batch_size = BATCH_SIZE)
print("The loss of this model: %.2f" % (score))
print("The accuracy of this model: %.2f" % (acc))
# Out:
# 90/90 - 223s - loss: 0.2290 - acc: 0.9007
# The loss of this model: 0.23
# The accuracy of this model: 0.90

# %%
util.plot_accuracy_loss(history, 'BiLSTM')

# %% [markdown]
# # **Prediction**

# %%
y_pred = model.predict(test_converted)

# %%
test, pred = util.plot_confusion_matrix(y_pred, target_converted_test, 'BiLSTM')
# Out:
# Confusion Matrix:
#  [[54330  7849  2364]
#  [ 5220 54048  1273]
#  [  648   846 56737]]

# %%
print("Classification Report: ", classification_report(test, pred))
# Out:
# Classification Report:                precision    recall  f1-score   support
#
#            0       0.90      0.84      0.87     64543
#            1       0.86      0.89      0.88     60541
#            2       0.94      0.97      0.96     58231
#
#     accuracy                           0.90    183315
#    macro avg       0.90      0.90      0.90    183315
# weighted avg       0.90      0.90      0.90    183315
